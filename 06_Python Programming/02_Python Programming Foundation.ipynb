# %% [markdown]
# # **Hello World**
# Five key topics that we need to know
# - variable
# - data type
# - data structure
# - control flow
# - function

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # List

# %%
movies = ["The Dark Knight", "Superman", "Beekeper"]

for movie in movies:
    print(movie)
# Out:
# The Dark Knight
# Superman
# Beekeper

# %%
movies = movies + ["Titanic", "Avatar"]
movie
# Out:
# 'Beekeper'

# %%
int("150") * 2
# Out:
# 300

# %%
# python dynamic typed language
x = "10"
type(x)
# Out:
# str

# %%
# python type hint
name: str = "toy"
gpa: float = 3.45
age: int = 36
movie_lover: bool = True

print(name, gpa, age, movie_lover)
# Out:
# toy 3.45 36 True

# %% [markdown]
# # Tuple

# %%
friends = ("toy", "john", "doe", "toy","toy")
type(friends)
# Out:
# tuple

# %%
for name in friends:
	print("hi! " + name)
# Out:
# hi! toy
# hi! john
# hi! doe
# hi! toy
# hi! toy

# %%
# # Cannot update value in tuple
# friends[0] = "TOY"

# %%
friends.count("toy")
# Out:
# 3

# %%
age_friends = (35, 30, 28)

toy, john, doe = age_friends

print(toy, john, doe)
# Out:
# 35 30 28

# %% [markdown]
# # Dictionary

# %%
customer01 = {
    "name": "toy",
    "age": 36,
    "city": "Bangkok"
}

customer01
# Out:
# {'name': 'toy', 'age': 36, 'city': 'Bangkok'}

# %%
customer01["age"]
# Out:
# 36

# %%
customer01["name"] = "John Wick"
customer01["age"] = 49
customer01["city"] = "New York"

customer01
# Out:
# {'name': 'John Wick', 'age': 49, 'city': 'New York'}

# %%
## add new key
customer01["country"] = "United States"
customer01
# Out:
# {'name': 'John Wick',
#  'age': 49,
#  'city': 'New York',
#  'country': 'United States'}

# %%
customer01.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'country'])

# %%
customer01.values()
# Out:
# dict_values(['John Wick', 49, 'New York', 'United States'])

# %%
customer01.items()
# Out:
# dict_items([('name', 'John Wick'), ('age', 49), ('city', 'New York'), ('country', 'United States')])

# %%
for item in customer01.items():
	print(item[0])
# Out:
# name
# age
# city
# country

# %%
customer01["age"]
# Out:
# 49

# %%
customer01 = {
    "name": "toy",
    "age": 36,
    "city": "Bangkok"
}
customer01.get("Name")

# %%
# customer01 = {
#     "name": "toy",
#     "age": 36,
#     "city": "Bangkok"
# }
# customer01["Name"]

# %%
customer01 = {
    "name": "toy",
    "age": 36,
    "city": "Bangkok"
}

del customer01["name"]
# or
customer01.pop("name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-cf9999d33c5e> in <cell line: 9>()
#       7 del customer01["name"]
#       8 # or
# ----> 9 customer01.pop("name")
#
# KeyError: 'name'

# %% [markdown]
# # Set

# %%
numbers = [1,1,2,3,4,5,5,6,9,9]

set(numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
set_a = {"banana", "apple"}
set_b = {"banana", "orange"}
print(set_a)
print(set_b)
# Out:
# {'banana', 'apple'}
# {'orange', 'banana'}

# %%
set_a = {"banana", "apple"}
set_b = {"banana", "orange"}

# union
set_a | set_b
# Out:
# {'apple', 'banana', 'orange'}

# %%
set_a = {"banana", "apple"}
set_b = {"banana", "orange"}

# Intersect
set_a & set_b
# Out:
# {'banana'}

# %% [markdown]
# # Control Flow
# - if
# - for
# - while

# %%
# if else

score = 88

if score >= 80:
    print("A")
elif score >= 70:
    print("B")
elif score >= 60:
    print("C")
else:
    print("Failed")
# Out:
# A

# %%
score = 85

print("passed") if score >= 80 else print("failed")
# Out:
# passed

# %%
# function
def grading(score):
    if score >= 80:
        return "A"
    elif score >= 70:
        return "B"
    elif score >= 60:
        return "C"
    else:
        return "Failed"
grading(80)
# Out:
# 'A'

# %%
# for loop
artists = ["Taylor Swift",
           "Spice Girls",
           "Backstreet Boys"]

for artist in artists:
    print(artist.split(" ")[0].upper())
# Out:
# TAYLOR
# SPICE
# BACKSTREET

# %%
# for loop
artists = ["Taylor Swift",
           "Spice Girls",
           "Backstreet Boys"]

for artist in artists:
		first_name = artist.split(" ")[0].upper()
		if first_name == "TAYLOR":
		    print("Greeeeeed! I'm going to see you in Japan.")
		else:
				print(first_name)
# Out:
# Greeeeeed! I'm going to see you in Japan.
# SPICE
# BACKSTREET

# %%
# for loop
artists = ["Taylor Swift",
           "Spice Girls",
           "Backstreet Boys"]

# list comprehension
upper_artists = [a.upper() for a in artists]

print(upper_artists)
# Out:
# ['TAYLOR SWIFT', 'SPICE GIRLS', 'BACKSTREET BOYS']

# %%
# while loop
n = 1 # counter
while n < 5:
    print("hi!")
    n += 1 # update value for stop loop
# Out:
# hi!
# hi!
# hi!
# hi!

# %% [markdown]
# # Game Function

# %%
def game():
    print("This is a test game!")
    while True:
        user_input = input("Do you want to continue or stop?")
        if user_input == "stop":
            print("Game stop!")
            break
        else:
            print("Let's continue.")

# %%
game()
# Out:
# This is a test game!
# Do you want to continue or stop?go
# Let's continue.
# Do you want to continue or stop?ope
# Let's continue.
# Do you want to continue or stop?n
# Let's continue.
# Do you want to continue or stop?stop
# Game stop!

# %% [markdown]
# # Object Oriented Programming

# %%
class Book: # ชื่อ Class ตัวอักษาตัวแรกจะต้องเป็นตัวอักษรตัวใหญ่เท่านั้น
    def __init__(self, name, year, author):
        self.name = name
        self.year = year
        self.author = author

# %%
book1 = Book("Think like a freak", 2010, "Dubner")
book2 = Book("Business Made Simple", 2018, "Donald Miller")
book3 = Book("Data Science for Business", 2015, "Wiley")

# %%
book1

# %%
book1.author
# Out:
# 'Dubner'

# %%
book3.year
# Out:
# 2015

# %%
class Dog:
    def __init__(self, name, age, specie):
        self.name = name
        self.age = age
        self.specie = specie

    def sitting(self):
        print("I'm sitting on the bed")

    def get_older(self, year):
        self.age += year
        print(f"I'm getting older {year} year.")

# %%
dog1 = Dog("Andy", 3, "chihuahua")
print(dog1.name, dog1.age, dog1.specie)
# Out:
# Andy 3 chihuahua

# %%
dog1.sitting()
# Out:
# I'm sitting on the bed

# %%
dog1.get_older(2)
# Out:
# I'm getting older 2 year.

# %%
dog1.age
# Out:
# 5
