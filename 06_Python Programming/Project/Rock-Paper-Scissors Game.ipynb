# %%
import random

def game():
    ## introduction
    print("Hello Player, Welcome to the Rock-Paper-Scissors game")
    username = input("What's your name? ")
    print(f"Hi {username}, Welcome to the game!")
    print("\nPlease read below instructions first :)")
    print("\nThe winner will receive 1 point.")
    print("You can play as many turns as you want.")
    print("If you want to stop playing games")
    print("Please enter the command: 4")
    print("\nLet's start Rock-Paper-Scissors Game!!")
    print("Please enter the number of Rock-Paper-Scissors")
    print("1 = Hammer ✊🏻")
    print("2 = Paper 🖐🏻")
    print("3 = Scissors ✌🏻")
    print("4 = Quit")

    # set initial value.
    hands = ["Hammer ✊🏻", "Paper 🖐🏻", "Scissors ✌🏻"]
    score_player = 0
    score_comp = 0

    # start the game
    while True:
        player_num = int(input("Choose your hand (1, 2, 3, or 4): "))
        if player_num == 4:
            print("\nGame has stopped!!")
            print(f"Your score is {score_player} point(s).")
            print(f"Computer's score is {score_comp} point(s).")
            if score_player > score_comp:
                print("You Win!! 😁")
            elif score_player < score_comp:
                print("You Lost 😭")
            elif score_player == 0 and score_comp == 0:
                print("Why don't you start playing the game? I'm waiting to play with you <3.")
            else:
                print("It's a draw with the Computer 🤝🏻")
            break
        elif player_num < 1 or player_num > 3:
            print("Please only enter 1, 2, 3, or 99")
            continue
        else:
            comp_hand = random.choice(hands)
            player_hand = hands[player_num-1]
            print(f"\nPlayer hand is {player_hand}.")
            print(f"Computer hand is {comp_hand}.")
            if ((player_hand == "Hammer" and comp_hand == "Scissors") or
                (player_hand == "Paper" and comp_hand == "Hammer") or
                (player_hand == "Scissors" and comp_hand == "Paper")):
                score_player += 1
                print("You win this turn, giving you 1 point.")
            elif player_hand == comp_hand:
                print("We draw this turn, no one scores")
            else:
                score_comp += 1
                print("You lost this turn, giving the computer 1 point.")

game()
# Out:
# Hello Player, Welcome to the Rock-Paper-Scissors game
# What's your name? ินหห
# Hi ินหห, Welcome to the game!
#
# Please read below instructions first :)
#
# The winner will receive 1 point.
# You can play as many turns as you want.
# If you want to stop playing games
# Please enter the command: 4
#
# Let's start Rock-Paper-Scissors Game!!
# Please enter the number of Rock-Paper-Scissors
# 1 = Hammer ✊🏻
# 2 = Paper 🖐🏻
# 3 = Scissors ✌🏻
# 4 = Quit
# Choose your hand (1, 2, 3, or 4): 1
#
# Player hand is Hammer ✊🏻.
# Computer hand is Paper 🖐🏻.
# You lost this turn, giving the computer 1 point.
# Choose your hand (1, 2, 3, or 4): 2
#
# Player hand is Paper 🖐🏻.
# Computer hand is Scissors ✌🏻.
# You lost this turn, giving the computer 1 point.
# Choose your hand (1, 2, 3, or 4): 3
#
# Player hand is Scissors ✌🏻.
# Computer hand is Paper 🖐🏻.
# You lost this turn, giving the computer 1 point.
# Choose your hand (1, 2, 3, or 4): 4
#
# Game has stopped!!
# Your score is 0 point(s).
# ...
